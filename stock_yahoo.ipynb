# %%
from pandas_datareader import data as pdr
import yfinance as yf

yf.pdr_override()

df = pdr.get_data_yahoo("035420.KS", start="2021-12-01", end="2021-12-31")
display(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close    Adj Close  Volume
# Date
# 2021-12-01  385000.0  392500.0  382000.0  390000.0  387706.1875  548840
# 2021-12-02  382500.0  399000.0  382000.0  398500.0  396156.1875  613006
# 2021-12-03  397500.0  402000.0  394500.0  402000.0  399635.6250  501099
# 2021-12-06  400500.0  400500.0  389500.0  392000.0  389694.4375  456773
# 2021-12-07  390500.0  392500.0  388500.0  391000.0  388700.3125  384366

# %%
import yfinance as yf

naver = yf.Ticker("035420.KS")
naver.financials
# Out:
#                                                              2022-12-31  \
# Tax Effect Of Unusual Items                           3034802084.526326
# Tax Rate For Calcs                                             0.378823
# Normalized EBITDA                                       1708306658150.0
# Total Unusual Items                                        8011138000.0
# Total Unusual Items Excluding Goodwill                     8011138000.0
# Net Income From Continuing Operation Net Minori...       760260876240.0
# Reconciled Depreciation                                  560908568000.0
# EBITDA                                                  1716317796150.0
# EBIT                                                    1155409228150.0
# Net Interest Income                                       31196131040.0
# Interest Expense                                          71692137000.0
# Interest Income                                           59164659000.0
# ...

# %%
apple = yf.Ticker("aapl")
print(apple)

apple.financials
# Out:
# yfinance.Ticker object <AAPL>
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.147
# Normalized EBITDA                                   129188000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              129188000000.0
# EBIT                                                117669000000.0
# Net Interest Income                                   -183000000.0
# Interest Expense                                      3933000000.0
# Interest Income                                       3750000000.0
# Normalized Income                                    96995000000.0
# ...

# %%
import yfinance as yf

tickers = yf.Tickers("msft aapl goog")
display(tickers.tickers)

# access each ticker using (example)
# Out:
# {'MSFT': yfinance.Ticker object <MSFT>,
#  'AAPL': yfinance.Ticker object <AAPL>,
#  'GOOG': yfinance.Ticker object <GOOG>}

# %%
display(tickers.tickers["MSFT"].info)
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
display(tickers.tickers["AAPL"].history(period="1mo"))
display(tickers.tickers["GOOG"].actions)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-12-13 00:00:00-05:00  195.089996  198.000000  194.850006  197.960007
# 2023-12-14 00:00:00-05:00  198.020004  199.619995  196.160004  198.110001
# 2023-12-15 00:00:00-05:00  197.529999  198.399994  197.000000  197.570007
# 2023-12-18 00:00:00-05:00  196.089996  196.630005  194.389999  195.889999
# 2023-12-19 00:00:00-05:00  196.160004  196.949997  195.889999  196.940002
# 2023-12-20 00:00:00-05:00  196.899994  197.679993  194.830002  194.830002
# 2023-12-21 00:00:00-05:00  196.100006  197.080002  193.500000  194.679993
# 2023-12-22 00:00:00-05:00  195.179993  195.410004  192.970001  193.600006
# 2023-12-26 00:00:00-05:00  193.610001  193.889999  192.830002  193.050003
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# 2023-12-28 00:00:00-05:00  194.139999  194.660004  193.169998  193.580002
# 2023-12-29 00:00:00-05:00  193.899994  194.399994  191.729996  192.529999
# ...

# %%
import pandas as pd
import yfinance as yf

# Specify the stock you want to analyze (e.g., Medco)
MEDC = yf.Ticker("MEDC.JK")

# %%
MEDC.financials
# Out:
#                                                       2022-12-31  \
# Tax Effect Of Unusual Items                           2290836.46
# Tax Rate For Calcs                                          0.22
# Normalized EBITDA                                   1300418020.0
# Total Unusual Items                                   10412893.0
# Total Unusual Items Excluding Goodwill                10412893.0
# Net Income From Continuing Operation Net Minori...   517101940.0
# Reconciled Depreciation                                5802156.0
# Reconciled Cost Of Revenue                          1066192282.0
# EBITDA                                              1310830913.0
# EBIT                                                1305028757.0
# Net Interest Income                                 -219810186.0
# Interest Expense                                     259427176.0
# Interest Income                                       39616990.0
# ...

# %%
MEDC.balancesheet
# Out:
#                                                      2022-12-31  \
# Treasury Shares Number                              110948255.0
# Ordinary Shares Number                            25025282997.0
# Share Issued                                      25136231252.0
# Net Debt                                           2551164440.0
# Total Debt                                         3337393654.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments    610968778.0
# Other Short Term Investments                         10970184.0
# Cash And Cash Equivalents                           599998594.0
# Cash Equivalents                                    115208438.0
# Cash Financial                                      484790156.0
#
#                                                      2021-12-31     2020-12-31
# Treasury Shares Number                              185831693.0     65527969.0
# ...

# %%
MEDC.cashflow
# Out:
#                                                     2022-12-31    2021-12-31  \
# Free Cash Flow                                     847897327.0   328534134.0
# Repurchase Of Capital Stock                                0.0    -6659577.0
# Repayment Of Debt                                -1097267500.0  -410242419.0
# Issuance Of Debt                                  1311809015.0   667353163.0
# Issuance Of Capital Stock                                  NaN           0.0
# Capital Expenditure                               -268540481.0  -111141162.0
# End Cash Position                                  599998594.0   480984828.0
# Beginning Cash Position                            480984828.0   297494075.0
# Effect Of Exchange Rate Changes                      4083292.0     -807936.0
# Changes In Cash                                    114930474.0   184298689.0
# Other Cash Adjustment Inside Changein Cash          -2972571.0    -2640321.0
# ...
